# %% [markdown]
# # Lab 1 - Pandas Intro

# %%
import pandas as pd

movies_df = pd.read_csv("movie.csv")
movies_df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## Questions

# %% [markdown]
# **0.** What is the average IMDB Score of all the movies?

# %%
movies_df.imdb_score.mean()
# Out:
# 6.4374288039056085

# %% [markdown]
# **1.** How many movies have "Star Wars" in the movie_title field?

# %%
from re import S

st_movies = movies_df[movies_df.movie_title.str.contains("Star Wars")]
len(st_movies)
# Out:
# 8

# %% [markdown]
# **2.** Which movie has the highest IMDB Score? What is that score?

# %%
movies_df.groupby('movie_title')[['imdb_score']].max().sort_values(['imdb_score'], ascending=False)
# Out:
#                                 imdb_score
# movie_title
# Towering Inferno                       9.5
# The Shawshank Redemption               9.3
# The Godfather                          9.2
# Dekalog                                9.1
# Kickboxer: Vengeance                   9.1
# ...                                    ...
# The Helix... Loaded                    1.9
# Disaster Movie                         1.9
# Superbabies: Baby Geniuses 2           1.9
# Foodfight!                             1.7
# Justin Bieber: Never Say Never         1.6
#
# [4916 rows x 1 columns]

# %% [markdown]
# **3**. Which movie has the lowest IMDB Score? What is that score?

# %%
#print(movies_df.imdb_score.min())
movies_df.groupby('movie_title')[['imdb_score']].min().sort_values(['imdb_score'], ascending=True)
# Out:
#                                 imdb_score
# movie_title
# Justin Bieber: Never Say Never         1.6
# Foodfight!                             1.7
# Superbabies: Baby Geniuses 2           1.9
# Disaster Movie                         1.9
# The Helix... Loaded                    1.9
# ...                                    ...
# Dekalog                                9.1
# Kickboxer: Vengeance                   9.1
# The Godfather                          9.2
# The Shawshank Redemption               9.3
# Towering Inferno                       9.5
#
# [4916 rows x 1 columns]

# %% [markdown]
# **4.** For each director, how many movies have they directed (from this dataset)?

# %%
movies_df.director_name.value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: director_name, Length: 2397, dtype: int64

# %% [markdown]
# **5.** What's the average duration of Action movies?

# %%
action_movies = movies_df[movies_df.genres.str.contains("Action")]
action_movies.duration.mean()
# Out:
# 110.67657657657658

# %% [markdown]
# **6.** Which PG-13 movie had the biggest budget?

# %%
# first sort movies based on rating
# then search that list for biggest budget
# 

movies_df[movies_df['content_rating'] == 'PG-13'].sort_values('budget', ascending = False)
#pg_movie = movies_df.content_rating.dropna()
#mask = ((movies_df.content_rating.notna()))
#mask
#movies_df
#movies_df.content_rating.notna()
#pg_movies = movies_df[movies_df.content_rating.str.contains("PG-13")]
# Out:
#                 color    director_name  num_critic_for_reviews  duration  \
# 2294            Color   Hayao Miyazaki                   174.0     134.0
# 2305            Color  Katsuhiro Ôtomo                   105.0     103.0
# 3779            Color     Carlos Saura                    35.0     115.0
# 1               Color   Gore Verbinski                   302.0     169.0
# 5               Color   Andrew Stanton                   462.0     132.0
# ...               ...              ...                     ...       ...
# 4679  Black and White    Stacy Peralta                    86.0      91.0
# 4754            Color     Jeff Nichols                    85.0      92.0
# 4814            Color      Eric Bugbee                     2.0      98.0
# 4835            Color    Peter Chelsom                    57.0     100.0
# 4914            Color      Daniel Hsia                    14.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# ...

# %% [markdown]
# **7.** How many movies were made in each year (title_year)?

# %%
movies_df.title_year.value_counts()
# Out:
# 2009.0    253
# 2014.0    243
# 2006.0    233
# 2013.0    231
# 2010.0    225
#          ...
# 1932.0      1
# 1916.0      1
# 1934.0      1
# 1925.0      1
# 1920.0      1
# Name: title_year, Length: 91, dtype: int64

# %% [markdown]
# **8.** How many movies had more than 10000 movie_facebook_likes?

# %%
mask = movies_df.movie_facebook_likes <= 10000
mask.sum

movies_df[mask]

movies_df[movies_df.movie_facebook_likes <= 10000].movie_facebook_likes.size
# Out:
# 3894

# %% [markdown]
# **9.** How many movies have "Tom Hanks" (as actor1, actor2, or actor3)?

# %%
mask = (
    (movies_df.actor_1_name == "Tom Hanks") | 
    (movies_df.actor_2_name == "Tom Hanks") |
    (movies_df.actor_3_name == "Tom Hanks")
)

#mask = movies_df.actor_1_name.isin(["Kevin Hart", "Dwayne Johnson"])
mask

movies_df[mask]
# Out:
#                 color     director_name  num_critic_for_reviews  duration  \
# 43              Color       Lee Unkrich                   453.0     103.0
# 91              Color   Robert Zemeckis                   188.0     100.0
# 129             Color        Ron Howard                   298.0     146.0
# 205             Color        Ron Howard                   294.0     174.0
# 307             Color        Tom Tykwer                   511.0     172.0
# 349             Color     John Lasseter                   191.0      82.0
# 390             Color   Robert Zemeckis                   221.0     143.0
# 451             Color        Sam Mendes                   226.0     117.0
# 530             Color  Steven Spielberg                   151.0     128.0
# 534             Color      Mike Nichols                   269.0     102.0
# 641             Color  Steven Spielberg                   219.0     169.0
# 648             Color        Ron Howard                   159.0     140.0
# ...

# %% [markdown]
# **10.**  What are the movies and number of voted users (num_voted_users) for movies that have less than 2 faces in the poster (facenumber_in_poster)?

# %%
# first narrow down to movies that have less than 2 faces in the poster
# then figure out the movies and number of voted users for those movies

pf_movies = movies_df[(movies_df.facenumber_in_poster < 2)]
pf_movies[ [ "movie_title", "num_voted_users", "facenumber_in_poster" ] ]
# Out:
#                                      movie_title  num_voted_users  \
# 0                                         Avatar           886204
# 1       Pirates of the Caribbean: At World's End           471220
# 2                                        Spectre           275868
# 3                          The Dark Knight Rises          1144337
# 4     Star Wars: Episode VII - The Force Awakens                8
# ...                                          ...              ...
# 4909                             The Mongol King               36
# 4910                                   Newlyweds             1338
# 4912                               The Following            73839
# 4913                        A Plague So Pleasant               38
# 4915                           My Date with Drew             4285
#
#       facenumber_in_poster
# 0                      0.0
# 1                      0.0
# 2                      1.0
# 3                      0.0
# 4                      0.0
# ...

# %% [markdown]
# **11.** What are the directors and number of director facebook likes for movies made beteween 2000 and 2004 (inclusive) sorted in descending order of director facebook likes?

# %%
movie_year = movies_df[ (movies_df.title_year >= 2000) & (movies_df.title_year <= 2004) ]
movie_year[ ["director_name", "director_facebook_likes","title_year"]].sort_values("director_facebook_likes", ascending=False)

#movies_df[["director_name", "director_facebook_likes","title_year"]].sort_values("director_facebook_likes", ascending=False)
# Out:
#              director_name  director_facebook_likes  title_year
# 1057     Christopher Nolan                  22000.0      2002.0
# 3646     Christopher Nolan                  22000.0      2000.0
# 1034         David Fincher                  21000.0      2002.0
# 2849     Denzel Washington                  18000.0      2002.0
# 2023          Kevin Spacey                  18000.0      2004.0
# ...                    ...                      ...         ...
# 2081           Kevin Smith                      0.0      2001.0
# 1935  Paul Thomas Anderson                      0.0      2002.0
# 1896              John Eng                      0.0      2003.0
# 1895       Cathy Malkasian                      0.0      2002.0
# 31               Sam Raimi                      0.0      2004.0
#
# [932 rows x 3 columns]

# %% [markdown]
# **12.** What are the missing values (NaN)? (in class practice)

# %%
#movies_df.duration.isna().sum()

# %%
#movies_df.duration.isna().sum() / len(movies_df)
#movies_df.duration.fillna( movies_df.duration.median(), inplace=True)
#movies_df.loc[4].duration
